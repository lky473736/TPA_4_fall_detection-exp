# %%
# !pip install thop ptflops
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ptflops
#   Downloading ptflops-0.7.5-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ptflops-0.7.5-py3-none-any.whl (19 kB)
# Installing collected packages: thop, ptflops
# Successfully installed ptflops-0.7.5 thop-0.1.1.post2209072238

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import os
import glob
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from thop import profile
import re
import time


class FallDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.LongTensor(y)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


class UMAFallLoader:
    def __init__(self, data_path, window_size=40, stride=20, sr=20, pre_sec=2.0, post_sec=2.0):
        self.data_path = data_path
        self.window_size = window_size
        self.stride = stride
        self.sr = sr
        self.pre_len = int(sr * pre_sec)
        self.post_len = int(sr * post_sec)

    def parse_filename(self, filename):
        pattern = r'UMAFall_Subject_(\d+)_(ADL|Fall)_([a-zA-Z_]+)_(\d+)_(\d{4}-\d{2}-\d{2})_.*\.csv'
        match = re.match(pattern, filename)

        if match:
            subject_id = int(match.group(1))
            activity_type = match.group(2)
            activity = match.group(3)
            trial = int(match.group(4))
            date = match.group(5)
            return subject_id, activity_type, activity, trial, date
        return None

    def read_all_sensors_file(self, filepath):
        print (filepath)
        sensor_data = {
            'RIGHTPOCKET': {'id': None, 'data': []},
            'CHEST': {'id': None, 'data': []},
            'WRIST': {'id': None, 'data': []},
            'WAIST': {'id': None, 'data': []},
            'ANKLE': {'id': None, 'data': []}
        }

        with open(filepath, 'r') as f:
            lines = f.readlines()
            for line in lines:
                if ';' in line and any(pos in line for pos in sensor_data.keys()):
                    parts = line.strip().split(';')
                    if len(parts) >= 3:
                        sensor_id = parts[1].strip()
                        position = parts[2].strip()
                        if position in sensor_data:
                            sensor_data[position]['id'] = sensor_id

            data_start = False
            for line in lines:
                if '% TimeStamp; Sample No;' in line:
                    data_start = True
                    continue

                if data_start:
                    try:
                        values = [float(v.strip()) for v in line.split(';')]
                        sensor_id = str(int(values[-1]))
                        sensor_type = int(values[-2])
                        data = values[2:5]

                        for position, info in sensor_data.items():
                            if info['id'] == sensor_id:
                                info['data'].append([*data, sensor_type])
                    except:
                        continue

        for position in sensor_data:
            if sensor_data[position]['data']:
                sensor_data[position]['data'] = np.array(sensor_data[position]['data'])
            else:
                sensor_data[position]['data'] = None

        return sensor_data

    def process_sensor_data(self, sensor_data):
        processed_data = {}
        valid_lengths = []

        for position, data in sensor_data.items():
            if data['data'] is not None:
                acc_mask = data['data'][:, -1] == 0
                gyro_mask = data['data'][:, -1] == 1
                mag_mask = data['data'][:, -1] == 2

                acc_data = data['data'][acc_mask][:, :3] if np.any(acc_mask) else np.array([])
                gyro_data = data['data'][gyro_mask][:, :3] if np.any(gyro_mask) else np.array([])
                mag_data = data['data'][mag_mask][:, :3] if np.any(mag_mask) else np.array([])

                if len(acc_data) > 0:
                    valid_lengths.append(len(acc_data))
                if len(gyro_data) > 0:
                    valid_lengths.append(len(gyro_data))
                if len(mag_data) > 0:
                    valid_lengths.append(len(mag_data))

        if not valid_lengths:
            return None

        min_length = min(valid_lengths)

        for position, data in sensor_data.items():
            if data['data'] is not None:
                acc_mask = data['data'][:, -1] == 0
                gyro_mask = data['data'][:, -1] == 1
                mag_mask = data['data'][:, -1] == 2

                if np.any(acc_mask):
                    acc_data = data['data'][acc_mask][:min_length, :3]
                    acc_cols = [f'{position.lower()}_acc_x', f'{position.lower()}_acc_y', f'{position.lower()}_acc_z']
                    processed_data.update(dict(zip(acc_cols, acc_data.T)))

                if np.any(gyro_mask):
                    gyro_data = data['data'][gyro_mask][:min_length, :3]
                    gyro_cols = [f'{position.lower()}_gyro_x', f'{position.lower()}_gyro_y', f'{position.lower()}_gyro_z']
                    processed_data.update(dict(zip(gyro_cols, gyro_data.T)))

                if np.any(mag_mask):
                    mag_data = data['data'][mag_mask][:min_length, :3]
                    mag_cols = [f'{position.lower()}_mag_x', f'{position.lower()}_mag_y', f'{position.lower()}_mag_z']
                    processed_data.update(dict(zip(mag_cols, mag_data.T)))

        if not processed_data:
            return None

        return pd.DataFrame(processed_data)

    def generate_pre_post_labels(self, raw_labels):
        labels = raw_labels.copy()
        n = len(labels)

        for i in range(n):
            if i < n - 1 and labels[i] == 1 and labels[i + 1] != 1:
                end_idx = min(i + 1 + self.post_len, n)
                labels[i+1:end_idx] = 3

        for i in range(n):
            if raw_labels[i] == 1 and (i == 0 or raw_labels[i-1] == 0):
                start_idx = max(0, i - self.pre_len)
                labels[start_idx:i] = 2

        return labels

    def sliding_window(self, data, labels):
        windows = []
        window_labels = []

        for i in range(0, len(data) - self.window_size + 1, self.stride):
            window = data[i:i + self.window_size]
            label_segment = labels[i:i + self.window_size]

            unique, counts = np.unique(label_segment, return_counts=True)
            label_dict = dict(zip(unique, counts))

            threshold = int(self.window_size * 0.1)

            if label_dict.get(1, 0) >= threshold:
                final_label = 1
            elif label_dict.get(3, 0) >= threshold:
                final_label = 3
            elif label_dict.get(2, 0) >= threshold:
                final_label = 2
            else:
                final_label = 0

            windows.append(window)
            window_labels.append(final_label)

        return np.array(windows), np.array(window_labels)

    def _sample_per_class(self, X, y, n_samples_per_class):
        sampled_X, sampled_y = [], []
        for class_id in range(4):
            class_indices = np.where(y == class_id)[0]
            n_available = len(class_indices)

            if n_available == 0:
                print(f"Warning: No samples found for class {class_id} in this split.")
                continue

            # [FIXED] Oversampling 방지: 요청된 수와 실제 수 중 최소값을 선택
            n_to_sample = min(n_samples_per_class, n_available)

            if n_available < n_samples_per_class:
                 print(f"Warning: Class {class_id} has only {n_available} samples. Using all {n_to_sample} samples (Requested: {n_samples_per_class}).")

            # [FIXED] replace=False로 설정하여 중복 샘플링(Oversampling) 방지
            selected = np.random.choice(class_indices, n_to_sample, replace=False)

            sampled_X.append(X[selected])
            sampled_y.append(y[selected])

        return np.concatenate(sampled_X, axis=0), np.concatenate(sampled_y, axis=0)

    def prepare_dataset(self, train_samples_per_class, val_samples_per_class, test_samples_per_class):
        all_files = glob.glob(os.path.join(self.data_path, "*.csv"))

        print("\n" + "="*80)
        print("Loading UMAFall Dataset (Concatenated Mode)")
        print("="*80)

        subject_data = {}

        for file in all_files:
            filename = os.path.basename(file)
            info = self.parse_filename(filename)

            if info:
                subject_id = info[0]
                sensor_data = self.read_all_sensors_file(file)
                df = self.process_sensor_data(sensor_data)

                if df is not None:
                    df['activity'] = info[2]

                    if subject_id not in subject_data:
                        subject_data[subject_id] = []
                    subject_data[subject_id].append(df)

        subjects = sorted(subject_data.keys())
        print(f"Total subjects found: {len(subjects)}")

        all_windows_raw = []
        all_window_labels = []

        print("\n" + "="*80)
        print("Processing all subjects...")
        print("="*80)

        for subject in subjects:
            dfs = subject_data.get(subject, [])
            if not dfs: continue

            subject_df = pd.concat(dfs, ignore_index=True)
            subject_df['activity'] = subject_df['activity'].map(
                lambda x: 1 if x in ['forwardFall', 'backwardFall', 'lateralFall'] else 0
            )
            subject_df = subject_df.dropna()

            sensor_columns = [col for col in subject_df.columns if any(x in col for x in ['acc', 'gyro', 'mag'])]
            if not sensor_columns: continue

            sensor_data_raw = subject_df[sensor_columns].values
            labels = subject_df['activity'].values

            labels_4class = self.generate_pre_post_labels(labels)

            windows, window_labels = self.sliding_window(sensor_data_raw, labels_4class)
            if windows.size == 0: continue

            all_windows_raw.append(windows)
            all_window_labels.append(window_labels)

            print(f"Subject {subject}: {len(windows)} windows generated.")

        X_all_raw = np.concatenate(all_windows_raw, axis=0)
        y_all = np.concatenate(all_window_labels, axis=0)

        print("\n" + "="*80)
        print(f"Total windows generated (pre-split): {len(X_all_raw)}")
        print(f"Class distribution (pre-split): {np.bincount(y_all, minlength=4)}")

        indices = np.arange(len(y_all))

        train_val_indices, test_indices = train_test_split(
            indices, test_size=0.2, random_state=42, stratify=y_all
        )

        train_indices, val_indices = train_test_split(
            train_val_indices, test_size=0.2, random_state=42, stratify=y_all[train_val_indices]
        )

        X_train_raw = X_all_raw[train_indices]
        y_train_unb = y_all[train_indices]

        X_val_raw = X_all_raw[val_indices]
        y_val_unb = y_all[val_indices]

        X_test_raw = X_all_raw[test_indices]
        y_test_unb = y_all[test_indices]

        print("\n" + "="*80)
        print("Scaling data...")
        print("="*80)

        scaler = StandardScaler()

        n_features = X_train_raw.shape[2]
        X_train_2d = X_train_raw.reshape(-1, n_features)
        scaler.fit(X_train_2d)

        X_train_scaled = scaler.transform(X_train_2d).reshape(X_train_raw.shape)

        X_val_scaled = scaler.transform(X_val_raw.reshape(-1, n_features)).reshape(X_val_raw.shape)
        X_test_scaled = scaler.transform(X_test_raw.reshape(-1, n_features)).reshape(X_test_raw.shape)

        print(" ✓ Scaler fitted on train data and applied to all splits.")

        print("\n" + "="*80)
        print("Sampling data per class...")
        print("="*80)

        train_X, train_y = self._sample_per_class(X_train_scaled, y_train_unb, train_samples_per_class)
        val_X, val_y = self._sample_per_class(X_val_scaled, y_val_unb, val_samples_per_class)
        test_X, test_y = self._sample_per_class(X_test_scaled, y_test_unb, test_samples_per_class)

        print("\n" + "="*80)
        print("Final Dataset Statistics")
        print("="*80)
        print(f"Train: {train_X.shape}, Class dist: {np.bincount(train_y, minlength=4)}")
        print(f"Val:   {val_X.shape}, Class dist: {np.bincount(val_y, minlength=4)}")
        print(f"Test:  {test_X.shape}, Class dist: {np.bincount(test_y, minlength=4)}")

        return train_X, train_y, val_X, val_y, test_X, test_y


class FormalTPA(nn.Module):
    def __init__(self, dim, heads=4, tau=1.0, bias_scale=1.0):
        super().__init__()
        assert dim % heads == 0
        self.dim = dim
        self.heads = heads
        self.dim_head = dim // heads
        self.scale = self.dim_head ** -0.5
        self.tau = tau
        self.bias_scale = bias_scale

        self.q_proj = nn.Linear(dim, dim)
        self.k_proj = nn.Linear(dim, dim)
        self.v_proj = nn.Linear(dim, dim)
        self.out_proj = nn.Linear(dim, dim)

        self.delta_norm = nn.LayerNorm(dim)
        self.delta_act = nn.GELU()
        self.delta_net = nn.Sequential(
            nn.Linear(dim, dim * 2),
            nn.GELU(),
            nn.Linear(dim * 2, dim),
            nn.GELU(),
            nn.Linear(dim, heads * 2)
        )
        self.res_norm = nn.LayerNorm(dim)

    def forward(self, x):
        B, T, D = x.shape
        H, Dh = self.heads, self.dim_head

        delta = torch.zeros_like(x)
        delta[:, 1:, :] = x[:, 1:, :] - x[:, :-1, :]
        delta = self.delta_norm(delta)

        gate_scores = self.delta_net(delta)
        logit_bias_scores, value_gate_logits = torch.chunk(gate_scores, 2, dim=-1)

        logit_bias_weights = F.softmax(logit_bias_scores.transpose(1, 2) / self.tau, dim=-1)
        logit_bias = self.bias_scale * logit_bias_weights.unsqueeze(2)

        value_gate = torch.sigmoid(value_gate_logits).permute(0, 2, 1).unsqueeze(-1)

        q = self.q_proj(x).view(B, T, H, Dh).permute(0, 2, 1, 3)
        k = self.k_proj(x).view(B, T, H, Dh).permute(0, 2, 1, 3)
        v = self.v_proj(x).view(B, T, H, Dh).permute(0, 2, 1, 3)

        v_gated = v * value_gate

        logits = torch.matmul(q, k.transpose(-2, -1)) * self.scale
        logits = logits + logit_bias
        attn = F.softmax(logits, dim=-1)

        out = torch.matmul(attn, v_gated)
        out = out.permute(0, 2, 1, 3).reshape(B, T, D)
        out = self.out_proj(out)
        out = self.res_norm(x + out)

        return out, logit_bias_weights


class TPAFallModel(nn.Module):
    def __init__(self, in_ch, dim, num_classes, heads, tau, bias_scale, num_layers=2):
        super().__init__()

        self.input_proj = nn.Linear(in_ch, dim)

        self.tpa_layers = nn.ModuleList([
            FormalTPA(dim, heads, tau, bias_scale) for _ in range(num_layers)
        ])

        self.fc = nn.Linear(dim, num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.input_proj(x)

        attn_maps = None
        for tpa in self.tpa_layers:
            x, attn_maps = tpa(x)

        x_global = x.mean(dim=1)
        x_global = self.dropout(x_global)

        out = self.fc(x_global)
        return out, attn_maps


def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    correct = 0
    total = 0

    for X, y in loader:
        X, y = X.to(device), y.to(device)

        optimizer.zero_grad()
        outputs, _ = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * X.size(0)
        _, predicted = outputs.max(1)
        total += y.size(0)
        correct += predicted.eq(y).sum().item()

    return total_loss / total, 100. * correct / total


def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    all_attn_maps = []

    with torch.no_grad():
        for X, y in loader:
            X, y = X.to(device), y.to(device)
            outputs, attn_maps = model(X)
            loss = criterion(outputs, y)

            total_loss += loss.item() * X.size(0)
            _, predicted = outputs.max(1)
            total += y.size(0)
            correct += predicted.eq(y).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(y.cpu().numpy())
            all_attn_maps.append(attn_maps.cpu().numpy())

    # 데이터가 없는 경우를 대비
    if not all_attn_maps:
        return total_loss / total if total > 0 else 0, \
               100. * correct / total if total > 0 else 0, \
               all_preds, all_labels, None

    all_attn_maps_np = np.concatenate(all_attn_maps, axis=0)
    return total_loss / total, 100. * correct / total, all_preds, all_labels, all_attn_maps_np


def plot_attention_maps(X_data, attn_maps, gts, preds, num_samples=3):
    if attn_maps is None or len(X_data) == 0:
        print("No data to plot attention maps.")
        return

    gts = np.array(gts)
    preds = np.array(preds)
    labels_map = {0: 'ADL', 1: 'Fall', 2: 'Pre', 3: 'Post'}

    correct_fall_indices = np.where((gts == 1) & (preds == 1))[0]
    pre_as_adl_indices = np.where((gts == 2) & (preds == 0))[0]

    if not os.path.exists('attention_plots'):
        os.makedirs('attention_plots')

    def plot_sample(indices, title_prefix, num):
        if len(indices) == 0:
            print(f"No samples found for {title_prefix}")
            return

        selected_indices = np.random.choice(indices, min(num, len(indices)), replace=False)

        for i, idx in enumerate(selected_indices):
            # idx가 X_data 범위를 벗어나는지 확인
            if idx >= len(X_data):
                print(f"Warning: Index {idx} out of bounds for X_data (len {len(X_data)}). Skipping plot.")
                continue

            signal = X_data[idx]
            attn = attn_maps[idx]
            attn_avg = np.mean(attn, axis=0)

            true_label = labels_map.get(gts[idx], 'Unknown')
            pred_label = labels_map.get(preds[idx], 'Unknown')

            fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12),
                                                 gridspec_kw={'height_ratios': [2, 2, 1]})

            if signal.shape[1] > 3:
                ax1.plot(signal[:, 0:3], label=['AccX', 'AccY', 'AccZ'])
                ax1.set_ylabel('Scaled Acc (e.g., Chest)')
            else:
                ax1.plot(signal[:, 0], label='Sensor 0')
                ax1.set_ylabel('Scaled Sensor 0')
            ax1.legend(loc='upper right')
            ax1.set_title(f"Sample {i+1} - {title_prefix} (Index {idx})\nTrue: {true_label}, Pred: {pred_label}")
            ax1.set_xlabel('Time Step')

            sns.heatmap(attn, cmap='viridis', ax=ax2, cbar=True,
                        yticklabels=[f'Head {h}' for h in range(attn.shape[0])])
            ax2.set_title('Attention Head Heatmap (TPA Delta-Bias Weights)')
            ax2.set_xlabel('Time Step')

            ax3.plot(attn_avg, color='r')
            ax3.set_title('Average Attention Weight Across Heads')
            ax3.set_xlabel('Time Step')
            ax3.set_ylabel('Avg. Weight')
            ax3.set_xlim(0, len(attn_avg)-1)

            plt.tight_layout()
            plt.savefig(f'attention_plots/{title_prefix}_sample_{i+1}.png', dpi=150)
            plt.close(fig)

    print("\n" + "="*80)
    print("Generating Attention Plots...")
    print("="*80)

    plot_sample(correct_fall_indices, "Correct_Fall", num_samples)
    plot_sample(pre_as_adl_indices, "Incorrect_Pre_as_ADL", num_samples)

    print(f"Attention plots saved to 'attention_plots/' directory.")


def main():
    CONFIG = {
        'window_size': 40,
        'stride': 20,
        'batch_size': 512,
        'epochs': 100,
        'hidden_dim': 256,
        'umafall_path': "/content/drive/MyDrive/HAR_Dataset/UMAFALL",
        'tpa_heads': 8,
        'tpa_tau': 1.0,
        'tpa_bias_scale': 1.0,
        'tpa_layers': 3,
        'class_weights': [1.0, 5.0, 8.0, 8.0],
        'sr': 20,
        'pre_sec': 2.0,
        'post_sec': 2.0,
        'train_samples_per_class': 1000,
        'val_samples_per_class': 500,
        'test_samples_per_class': 500,
    }

    np.random.seed(42)
    torch.manual_seed(42)

    loader = UMAFallLoader(CONFIG['umafall_path'],
                           window_size=CONFIG['window_size'],
                           stride=CONFIG['stride'],
                           sr=CONFIG['sr'],
                           pre_sec=CONFIG['pre_sec'],
                           post_sec=CONFIG['post_sec'])

    train_X, train_y, val_X, val_y, test_X, test_y = loader.prepare_dataset(
        train_samples_per_class=CONFIG['train_samples_per_class'],
        val_samples_per_class=CONFIG['val_samples_per_class'],
        test_samples_per_class=CONFIG['test_samples_per_class']
    )

    train_ds = FallDataset(train_X, train_y)
    val_ds = FallDataset(val_X, val_y)
    test_ds = FallDataset(test_X, test_y)

    train_loader = DataLoader(train_ds, batch_size=CONFIG['batch_size'], shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=CONFIG['batch_size'], shuffle=False)
    test_loader = DataLoader(test_ds, batch_size=CONFIG['batch_size'], shuffle=False)

    print("\n" + "="*80)
    print("Build Model (TPA-Only)")
    print("="*80)

    # 데이터셋이 비어있을 경우 예외 처리
    if len(train_X) == 0:
        print("Error: No training data loaded. Exiting.")
        return

    in_channels = train_X.shape[2]
    print(f"Input channels: {in_channels}")
    print(f"Window size: {CONFIG['window_size']}")

    model = TPAFallModel(
        in_ch=in_channels,
        dim=CONFIG['hidden_dim'],
        num_classes=4,
        heads=CONFIG['tpa_heads'],
        tau=CONFIG['tpa_tau'],
        bias_scale=CONFIG['tpa_bias_scale'],
        num_layers=CONFIG['tpa_layers']
    )
    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f" ✓ Parameters: {n_params:,}")
    # [FIXED] 'tLPA_layers' -> 'tpa_layers' 오타 수정
    print(f" ✓ TPA: {CONFIG['tpa_layers']} layers, heads={CONFIG['tpa_heads']}, dim={CONFIG['hidden_dim']}")

    weights = torch.FloatTensor(CONFIG['class_weights'])
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    weights = weights.to(device)

    criterion = nn.CrossEntropyLoss(weight=weights)
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

    print("\n" + "="*80)
    print("Class Weights:")
    print("="*80)
    for name, w in zip(['ADL','Fall','Pre','Post'], CONFIG['class_weights']):
        print(f" {name:7s}: {w:.2f}")

    print("\n" + "="*80)
    print("Training Start")
    print("="*80)

    best_val_acc = 0
    best_epoch = 0

    for epoch in range(CONFIG['epochs']):
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        val_loss, val_acc, _, _, _ = evaluate(model, val_loader, criterion, device)

        scheduler.step(val_loss)

        print(f"Epoch {epoch+1:2d}/{CONFIG['epochs']} | "
              f"Train Loss: {train_loss:.4f} Acc: {train_acc:.2f}% | "
              f"Val Loss: {val_loss:.4f} Acc: {val_acc:.2f}%")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_epoch = epoch + 1
            torch.save(model.state_dict(), 'best_model.pth')

    print("\n" + "="*80)
    print(f"Best Validation Accuracy: {best_val_acc:.2f}% at Epoch {best_epoch}")
    print("="*80)

    model.load_state_dict(torch.load('best_model.pth'))
    test_loss, test_acc, preds, gts, all_attn_maps = evaluate(model, test_loader, criterion, device)

    print("\n" + "="*80)
    print("Test Set Performance")
    print("="*80)
    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.2f}%")

    print("\n" + classification_report(gts, preds, labels=[0,1,2,3],
                                target_names=['ADL','Fall','Pre-fall','Post-fall'],
                                digits=4, zero_division=0))

    cm = confusion_matrix(gts, preds, labels=[0,1,2,3])
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['ADL','Fall','Pre','Post'],
                yticklabels=['ADL','Fall','Pre','Post'])
    plt.title('Confusion Matrix - TPA-Only Model (Concatenated Split)')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
    print("\nConfusion matrix saved to 'confusion_matrix.png'")

    dummy_input = torch.randn(1, CONFIG['window_size'], in_channels).to(device)
    flops, params = profile(model, inputs=(dummy_input,), verbose=False)
    print(f"\nModel Statistics:")
    print(f"  Params (M):  {params / 1e6:.2f}")
    print(f"  FLOPs (M):   {flops / 1e6:.2f}")

    model.eval()
    times = []
    with torch.no_grad():
        for _ in range(100):
            start = time.time()
            _ = model(dummy_input)
            if torch.cuda.is_available():
                torch.cuda.synchronize()
            times.append((time.time() - start) * 1000)
    print(f"  Inference (ms): {np.mean(times[10:]):.2f}")

    # test_X는 '샘플링 된' 데이터셋이므로, plot_attention_maps에 그대로 전달합니다.
    # evaluate 함수에서 반환된 gts, preds, all_attn_maps는 test_loader 순서와 일치하며,
    # test_loader는 test_X, test_y로 만들어졌으므로 인덱스가 일치합니다.
    plot_attention_maps(test_X, all_attn_maps, gts, preds, num_samples=3)


if __name__ == '__main__':
    main()
# Out:
# ================================================================================
# Loading UMAFall Dataset (Concatenated Mode)
# ================================================================================
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_2_2016-05-29_20-48-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_backwardFall_2_2016-06-13_13-19-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_lateralFall_2_2016-06-13_20-50-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_Walking_3_2017-04-14_23-45-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_lateralFall_3_2016-06-07_21-28-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_backwardFall_5_2016-06-13_21-53-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Sitting_GettingUpOnAChair_1_2016-06-04_21-30-12.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_3_2016-05-29_20-38-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_MakingACall_2_2016-12-03_17-23-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Walking_3_2016-06-13_21-13-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_Fall_lateralFall_3_2016-06-17_19-24-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Bending_2_2016-06-04_21-23-35.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_forwardFall_3_2016-06-13_21-41-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Sitting_GettingUpOnAChair_2_2016-06-13_20-35-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_10_2016-06-01_22-55-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_Fall_backwardFall_3_2016-06-13_18-38-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_HandsUp_2_2017-04-26_19-43-25.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Sitting_GettingUpOnAChair_2_2016-06-13_13-04-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Aplausing_2_2016-11-28_16-32-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_forwardFall_5_2016-06-13_20-54-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_GoUpstairs_2_2016-06-04_21-38-28.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_LyingDown_OnABed_2_2016-06-13_21-26-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_6_2016-05-29_21-55-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_backwardFall_6_2016-06-07_21-40-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_lateralFall_3_2016-06-13_20-50-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_HandsUp_4_2016-11-28_16-31-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Hopping_2_2016-06-07_21-17-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Jogging_3_2016-06-13_20-41-46.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Bending_2_2016-06-13_20-26-15.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_forwardFall_2_2016-06-13_21-40-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_1_2016-06-15_21-14-04.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Sitting_GettingUpOnAChair_3_2016-06-04_21-54-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_08_Fall_forwardFall_1_2016-06-18_14-27-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_Fall_lateralFall_3_2016-06-03_20-06-47.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_5_2016-05-29_21-54-01.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Jogging_6_2016-05-31_18-36-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_forwardFall_1_2016-06-13_13-13-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_5_2016-11-28_16-24-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_6_2016-05-31_18-25-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Bending_2_2016-06-10_17-34-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Hopping_1_2016-06-13_21-15-47.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Hopping_1_2016-06-03_19-41-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Bending_2_2016-06-03_19-32-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_backwardFall_4_2016-06-15_21-37-33.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_7_2016-06-02_00-07-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Hopping_1_2016-06-07_21-17-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_Walking_1_2017-04-14_23-25-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_MakingACall_1_2016-12-03_17-42-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_7_2016-06-01_23-12-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Hopping_5_2016-06-06_16-44-57.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_OpeningDoor_3_2017-04-14_23-57-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_lateralFall_2_2016-06-13_21-43-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_2_2016-11-27_14-26-35.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_MakingACall_1_2017-04-14_23-49-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Bending_1_2016-06-06_16-39-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Bending_2_2016-06-13_21-09-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_MakingACall_3_2017-03-27_22-29-15.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_HandsUp_3_2016-12-03_17-17-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_GoDownstairs_2_2016-06-06_15-56-28.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_Walking_1_2016-06-17_18-29-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_1_2016-05-29_20-34-24.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_Sitting_GettingUpOnAChair_3_2017-04-14_23-48-14.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_GoUpstairs_1_2016-06-03_19-47-35.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Aplausing_2_2017-04-19_16-57-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Hopping_3_2016-06-13_13-02-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_HandsUp_3_2017-03-27_22-31-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_Aplausing_3_2017-04-14_23-59-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_18_2016-06-01_22-09-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_14_2016-06-01_22-47-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_HandsUp_2_2016-12-03_17-16-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_4_2016-11-27_14-16-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_4_2016-05-31_18-38-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Aplausing_2_2016-12-03_17-14-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Hopping_1_2016-06-10_17-39-10.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_4_2016-11-27_14-27-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_MakingACall_1_2017-04-14_23-30-27.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Jogging_2_2016-06-10_17-45-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_08_Fall_forwardFall_2_2016-06-18_14-28-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_1_2016-05-29_20-42-47.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_LyingDown_OnABed_2_2016-06-13_18-31-46.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_OpeningDoor_3_2017-04-26_19-46-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_lateralFall_4_2016-06-10_18-01-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_Jogging_1_2016-06-17_18-30-49.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_ADL_Jogging_1_2016-06-17_19-13-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_GoDownstairs_2_2016-06-04_22-00-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_OpeningDoor_4_2016-11-27_16-46-36.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_forwardFall_4_2016-06-13_13-21-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_ADL_Sitting_GettingUpOnAChair_1_2016-06-17_20-58-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Bending_1_2016-06-13_20-25-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Walking_3_2016-06-13_13-00-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Hopping_1_2016-06-13_20-37-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Aplausing_3_2017-04-26_19-48-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_OpeningDoor_1_2017-04-14_23-36-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_Sitting_GettingUpOnAChair_3_2017-04-14_23-29-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_16_2016-06-01_22-34-36.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Aplausing_5_2016-11-27_16-52-48.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_GoDownstairs_3_2016-06-03_19-53-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_OpeningDoor_3_2016-11-28_16-43-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_LyingDown_OnABed_1_2016-06-10_17-46-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoDownstairs_3_2016-06-06_15-33-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Aplausing_3_2017-03-27_22-48-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_ADL_LyingDown_OnABed_2_2016-06-17_19-12-25.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_08_Fall_lateralFall_1_2016-06-18_14-28-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Jogging_3_2016-05-29_21-29-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_2_2016-06-15_21-18-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_Fall_forwardFall_1_2016-06-17_21-49-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_MakingACall_3_2016-12-03_17-24-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_forwardFall_2_2016-06-07_21-23-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_Fall_lateralFall_1_2016-06-17_18-41-12.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_LyingDown_OnABed_1_2016-06-13_21-24-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_lateralFall_1_2016-06-13_21-42-37.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_ADL_Bending_2_2016-06-17_20-56-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_Fall_forwardFall_3_2016-06-17_19-21-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Bending_1_2016-06-07_21-03-36.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Sitting_GettingUpOnAChair_2_2016-06-03_19-46-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_MakingACall_3_2017-04-19_12-35-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_backwardFall_1_2016-06-13_13-19-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_2_2016-11-27_14-05-49.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_14_2016-06-01_23-00-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_backwardFall_5_2016-06-07_21-39-33.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Hopping_1_2016-06-04_21-27-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_3_2016-11-27_14-14-49.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Hopping_2_2016-06-10_17-39-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_1_2016-05-29_20-51-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_backwardFall_4_2016-06-07_21-38-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_1_2016-11-28_16-22-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_lateralFall_2_2016-06-13_13-17-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_11_2016-06-01_22-57-03.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Jogging_1_2016-06-10_17-44-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_LyingDown_OnABed_1_2016-06-04_21-55-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_OpeningDoor_2_2016-11-27_16-45-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_forwardFall_6_2016-06-07_21-33-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_MakingACall_1_2016-11-28_16-27-25.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_4_2016-05-29_21-56-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_10_2016-06-01_22-39-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_1_2016-05-29_21-32-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_2_2016-11-27_14-09-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_LyingDown_OnABed_1_2016-06-04_21-33-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_Walking_3_2017-04-14_23-27-12.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_OpeningDoor_1_2017-04-14_23-55-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_Fall_backwardFall_1_2016-06-03_20-08-04.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Sitting_GettingUpOnAChair_2_2016-06-07_21-10-27.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_Sitting_GettingUpOnAChair_1_2017-04-14_23-28-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_Fall_forwardFall_3_2016-06-03_20-03-13.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_LyingDown_OnABed_2_2016-06-13_13-11-01.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_HandsUp_3_2017-04-19_16-52-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_8_2016-06-02_00-15-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Bending_3_2016-06-04_21-24-21.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_Fall_backwardFall_2_2016-06-17_18-44-01.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_LyingDown_OnABed_3_2016-06-04_21-57-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_Fall_forwardFall_4_2016-06-17_18-46-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_forwardFall_2_2016-06-13_20-45-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_forwardFall_4_2016-06-13_20-53-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Jogging_3_2016-06-13_21-33-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_OpeningDoor_3_2016-12-03_17-30-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Hopping_3_2016-06-06_16-45-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Walking_1_2016-06-10_17-36-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_OpeningDoor_3_2017-04-19_12-39-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Aplausing_1_2016-11-28_16-44-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_LyingDown_OnABed_1_2016-06-13_13-10-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_MakingACall_1_2017-03-27_22-27-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_1_2016-05-29_21-44-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Aplausing_1_2017-03-27_22-47-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_HandsUp_1_2017-04-26_19-42-49.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_forwardFall_4_2016-06-13_21-47-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Bending_2_2016-06-13_18-22-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_HandsUp_1_2017-04-19_12-36-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Walking_2_2016-06-06_16-42-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_MakingACall_1_2016-12-03_17-11-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Sitting_GettingUpOnAChair_3_2016-06-04_21-31-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_OpeningDoor_2_2017-04-19_12-39-04.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Bending_3_2016-06-13_12-57-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_Fall_backwardFall_3_2016-06-17_19-29-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_6_2016-11-27_14-12-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_2_2016-11-27_16-54-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_LyingDown_OnABed_1_2016-06-15_21-52-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Bending_4_2016-06-03_19-36-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_LyingDown_OnABed_2_2016-06-03_19-57-03.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Bending_2_2016-06-15_21-42-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_GoDownstairs_1_2016-06-04_21-58-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_Fall_forwardFall_2_2016-06-17_19-20-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_HandsUp_3_2016-11-27_16-42-03.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Walking_3_2016-06-07_21-07-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Aplausing_2_2017-04-19_12-41-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_OpeningDoor_3_2016-12-03_17-54-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_3_2016-11-28_16-23-24.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_backwardFall_5_2016-06-15_21-38-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Aplausing_1_2016-11-27_16-50-15.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_HandsUp_1_2017-03-27_22-43-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Bending_3_2016-06-13_18-22-57.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_Fall_lateralFall_1_2016-06-17_21-54-46.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Walking_3_2016-06-06_16-43-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_Fall_forwardFall_3_2016-06-17_21-53-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Aplausing_3_2016-11-28_16-45-47.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_7_2016-06-02_00-14-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_7_2016-06-02_00-02-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_Aplausing_1_2016-12-03_17-25-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoDownstairs_6_2016-06-06_15-38-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_OpeningDoor_1_2017-03-27_22-32-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_lateralFall_6_2016-06-10_18-03-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Sitting_GettingUpOnAChair_1_2016-06-13_13-03-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_MakingACall_2_2016-12-03_17-43-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_10_2016-06-01_22-14-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_4_2016-05-29_21-52-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_4_2016-05-31_18-47-14.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_forwardFall_6_2016-06-10_18-00-47.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Sitting_GettingUpOnAChair_2_2016-06-06_16-47-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Jogging_8_2016-06-02_00-17-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_OpeningDoor_1_2016-12-03_17-18-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_Fall_backwardFall_3_2016-06-17_18-44-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_lateralFall_4_2016-06-13_21-50-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_Fall_lateralFall_4_2016-06-17_19-28-33.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_forwardFall_6_2016-06-13_21-48-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_GoUpstairs_2_2016-06-04_21-59-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Sitting_GettingUpOnAChair_1_2016-06-10_17-41-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_13_2016-06-01_22-46-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_forwardFall_3_2016-06-10_17-51-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Bending_2_2016-06-13_12-57-13.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_Fall_forwardFall_1_2016-06-03_20-01-24.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_MakingACall_2_2017-04-26_19-41-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_backwardFall_2_2016-06-15_21-30-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_LyingDown_OnABed_3_2016-06-15_21-54-02.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_1_2016-05-29_21-37-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_lateralFall_5_2016-06-15_21-36-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_backwardFall_2_2016-06-07_21-30-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_Hopping_1_2016-06-06_15-44-04.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_backwardFall_3_2016-06-15_21-32-28.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Aplausing_3_2017-04-19_12-41-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Walking_2_2016-06-10_17-37-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_5_2016-11-27_14-33-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Walking_1_2016-06-15_21-43-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Aplausing_2_2017-04-26_19-47-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_forwardFall_1_2016-06-07_21-31-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Walking_2_2016-06-13_20-28-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_3_2016-05-29_21-47-46.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_3_2016-05-29_21-23-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_8_2016-06-01_22-37-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_HandsUp_3_2016-11-28_16-41-10.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_6_2016-11-27_14-17-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_2_2016-11-27_14-30-37.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Sitting_GettingUpOnAChair_2_2016-06-13_18-34-35.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Walking_1_2016-06-06_16-41-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_8_2016-06-01_22-53-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_GoUpstairs_3_2016-06-04_21-40-02.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Sitting_GettingUpOnAChair_3_2016-06-06_16-48-02.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_forwardFall_2_2016-06-10_17-50-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_MakingACall_3_2017-04-14_23-31-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Bending_1_2016-06-15_21-41-04.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_LyingDown_OnABed_1_2016-06-13_20-32-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_LyingDown_OnABed_2_2016-06-06_15-50-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_forwardFall_1_2016-06-13_20-43-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Bending_1_2016-06-13_12-56-21.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_2_2016-05-29_20-55-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Hopping_3_2016-06-13_20-39-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_forwardFall_4_2016-06-15_21-33-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_Fall_lateralFall_2_2016-06-17_19-23-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Walking_2_2016-06-13_21-12-36.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_OpeningDoor_2_2016-11-28_16-42-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_6_2016-05-31_18-41-33.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_Aplausing_1_2017-04-14_23-38-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_17_2016-06-01_22-35-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Hopping_1_2016-06-04_21-51-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_2_2016-05-29_21-35-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_8_2016-06-02_00-12-57.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_2_2016-05-29_20-52-13.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_HandsUp_5_2016-11-27_16-43-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_MakingACall_2_2016-11-28_16-28-01.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_Bending_1_2016-06-17_18-28-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_forwardFall_6_2016-06-13_20-55-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_Fall_backwardFall_2_2016-06-13_18-38-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_5_2016-11-27_14-28-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_LyingDown_OnABed_3_2016-06-10_17-48-27.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_Sitting_GettingUpOnAChair_3_2016-06-06_15-48-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Hopping_3_2016-06-15_21-48-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Sitting_GettingUpOnAChair_1_2016-06-06_16-46-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_08_ADL_Sitting_GettingUpOnAChair_1_2016-06-18_14-25-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_4_2016-11-28_16-24-03.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_backwardFall_2_2016-06-13_21-45-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_4_2016-11-27_16-56-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_6_2016-05-31_18-45-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_5_2016-05-29_21-59-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_3_2016-05-29_20-53-15.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_OpeningDoor_1_2017-03-27_22-45-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_Fall_forwardFall_2_2016-06-17_18-39-36.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_4_2016-05-31_18-30-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_MakingACall_1_2017-04-19_12-33-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_LyingDown_OnABed_1_2016-06-07_21-12-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Jogging_3_2016-06-07_21-20-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Bending_3_2016-06-13_21-10-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_lateralFall_3_2016-06-13_21-43-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_forwardFall_3_2016-06-07_21-24-37.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Jogging_1_2016-06-15_21-45-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Jogging_3_2016-06-13_13-08-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Jogging_2_2016-06-15_21-46-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Sitting_GettingUpOnAChair_3_2016-06-13_13-04-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Sitting_GettingUpOnAChair_3_2016-06-07_21-11-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_Sitting_GettingUpOnAChair_1_2017-04-14_23-46-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoDownstairs_4_2016-06-06_15-34-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Aplausing_1_2017-04-19_16-56-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_MakingACall_3_2017-03-27_22-42-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_12_2016-06-01_22-45-27.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_Fall_lateralFall_2_2016-06-03_20-05-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_backwardFall_1_2016-06-07_21-29-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_backwardFall_6_2016-06-10_18-05-33.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_lateralFall_5_2016-06-10_18-02-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_3_2016-11-27_14-31-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_3_2016-05-29_20-49-15.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_GoUpstairs_2_2016-06-03_19-49-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Jogging_1_2016-05-29_21-26-25.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_GoDownstairs_3_2016-06-04_22-03-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_15_2016-06-01_23-01-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_LyingDown_OnABed_3_2016-06-13_20-33-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_5_2016-11-27_16-57-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_6_2016-05-29_21-51-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_Bending_2_2016-06-04_15-07-21.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_9_2016-06-02_00-10-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_6_2016-05-31_18-32-13.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_11_2016-06-01_22-18-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_Fall_forwardFall_2_2016-06-17_21-49-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_1_2016-11-27_14-05-10.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_6_2016-11-27_14-08-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_5_2016-05-29_21-50-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_backwardFall_1_2016-06-10_17-56-03.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Walking_1_2016-06-13_20-27-49.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_MakingACall_2_2016-11-28_16-22-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_MakingACall_2_2017-04-14_23-31-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_GoDownstairs_3_2016-06-04_21-40-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Bending_1_2016-06-04_21-22-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Walking_2_2016-06-07_21-06-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_8_2016-06-02_00-09-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_LyingDown_OnABed_2_2016-06-13_21-25-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Hopping_3_2016-06-13_21-17-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Hopping_2_2016-06-15_21-48-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_backwardFall_5_2016-06-13_20-59-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_MakingACall_1_2017-03-27_22-41-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_08_ADL_Walking_1_2016-06-18_14-24-36.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_HandsUp_2_2016-11-28_16-30-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_Fall_forwardFall_3_2016-06-17_18-40-24.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_OpeningDoor_1_2017-04-14_23-36-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Walking_2_2016-06-15_21-44-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_HandsUp_2_2016-11-28_16-40-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_Walking_1_2017-04-14_23-44-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_6_2016-05-29_22-00-46.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_forwardFall_6_2016-06-15_21-34-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_08_Fall_backwardFall_1_2016-06-18_14-31-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_Walking_3_2016-06-06_15-42-40.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Bending_3_2016-06-04_21-47-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_LyingDown_OnABed_2_2016-06-04_21-34-37.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Aplausing_6_2016-11-27_16-53-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_3_2016-05-29_21-36-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_OpeningDoor_2_2017-04-26_19-45-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Sitting_GettingUpOnAChair_2_2016-06-15_21-50-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_5_2016-11-27_14-12-04.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Walking_3_2016-06-04_21-50-10.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Aplausing_1_2017-04-19_12-40-28.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_HandsUp_3_2017-04-26_19-44-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_LyingDown_OnABed_1_2016-06-06_15-49-27.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Sitting_GettingUpOnAChair_1_2016-06-13_18-33-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_GoUpstairs_1_2016-06-04_21-58-03.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_backwardFall_6_2016-06-13_20-59-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_lateralFall_4_2016-06-07_21-34-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Bending_1_2016-06-04_21-46-33.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Sitting_GettingUpOnAChair_2_2016-06-13_21-29-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_OpeningDoor_1_2017-04-19_16-53-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Hopping_3_2016-06-13_18-29-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Jogging_2_2016-05-29_21-28-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Bending_1_2016-06-10_17-33-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_HandsUp_1_2016-12-03_17-15-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_LyingDown_OnABed_2_2016-06-04_21-56-25.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_GoUpstairs_1_2016-06-06_16-51-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_Aplausing_3_2017-04-14_23-39-35.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_1_2016-11-27_14-13-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoUpstairs_4_2016-06-06_15-35-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Aplausing_2_2016-11-28_16-44-47.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_OpeningDoor_1_2017-04-26_19-45-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_4_2016-05-31_18-42-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_lateralFall_5_2016-06-13_20-56-57.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_HandsUp_3_2017-04-14_23-54-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_OpeningDoor_1_2017-04-19_12-38-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Walking_1_2016-06-04_21-25-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_GoDownstairs_2_2016-06-04_21-39-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_4_2016-05-29_21-49-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_ADL_Bending_3_2016-06-10_17-35-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_Sitting_GettingUpOnAChair_1_2016-06-17_18-31-49.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoUpstairs_2_2016-06-06_15-31-57.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_lateralFall_1_2016-06-10_17-53-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_lateralFall_1_2016-06-15_21-28-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_3_2016-11-27_16-56-02.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoUpstairs_6_2016-06-06_15-36-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Aplausing_1_2017-04-26_19-47-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_forwardFall_2_2016-06-15_21-22-29.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_MakingACall_1_2017-04-26_19-40-37.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoUpstairs_1_2016-06-06_15-31-14.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_LyingDown_OnABed_3_2016-06-13_18-32-22.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_5_2016-11-27_14-16-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Walking_2_2016-06-13_18-24-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_GoDownstairs_2_2016-06-03_19-50-47.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_forwardFall_4_2016-06-10_17-59-25.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_2_2016-05-29_21-45-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Sitting_GettingUpOnAChair_3_2016-06-03_19-44-02.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_ADL_Walking_3_2016-06-13_20-29-14.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_Walking_2_2017-04-14_23-44-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_ADL_Walking_1_2016-06-17_22-00-19.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Sitting_GettingUpOnAChair_1_2016-06-15_21-49-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_Fall_forwardFall_2_2016-06-03_20-02-25.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_lateralFall_2_2016-06-07_21-27-41.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_Bending_1_2016-06-06_16-37-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_HandsUp_2_2016-12-03_17-49-13.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_OpeningDoor_2_2017-04-19_16-55-00.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Jogging_2_2016-06-13_21-32-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_Walking_1_2016-06-06_15-41-15.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_backwardFall_1_2016-06-15_21-30-13.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoUpstairs_5_2016-06-06_15-36-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Walking_1_2016-06-04_21-48-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_MakingACall_2_2017-03-27_22-41-48.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_13_2016-06-01_22-30-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Walking_1_2016-06-13_18-23-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_Fall_backwardFall_5_2016-06-13_18-40-07.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_OpeningDoor_1_2016-12-03_17-52-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_OpeningDoor_1_2016-11-28_16-41-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_8_2016-06-02_00-04-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Hopping_3_2016-06-04_21-52-31.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_forwardFall_3_2016-06-13_20-47-36.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_lateralFall_1_2016-06-13_13-16-45.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_5_2016-05-31_18-24-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Walking_2_2016-06-03_19-39-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_14_2016-06-01_22-32-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_Walking_1_2016-06-17_18-29-24.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_15_2016-06-01_22-33-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_lateralFall_1_2016-06-15_21-14-53.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_17_Fall_backwardFall_3_2016-06-17_19-27-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_lateralFall_5_2016-06-07_21-35-39.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_forwardFall_5_2016-06-15_21-34-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_Walking_3_2016-06-04_21-26-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Bending_3_2016-06-15_21-43-01.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_13_ADL_LyingDown_OnABed_3_2016-06-06_16-50-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Walking_1_2016-06-03_19-38-06.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_Hopping_3_2016-06-06_15-45-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_6_2016-11-27_14-29-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_16_Fall_backwardFall_3_2016-06-17_21-59-35.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Hopping_2_2016-06-13_21-16-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_ADL_Walking_1_2016-06-13_12-58-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Sitting_GettingUpOnAChair_2_2016-06-04_21-53-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_12_ADL_Sitting_GettingUpOnAChair_1_2016-06-04_21-53-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_forwardFall_2_2016-06-13_20-48-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Aplausing_2_2016-11-27_16-50-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Walking_3_2016-06-03_19-40-03.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_MakingACall_3_2016-12-03_17-12-54.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_HandsUp_1_2017-04-14_23-32-44.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Bending_2_2016-05-29_20-36-13.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_LyingDown_OnABed_1_2016-06-17_18-34-10.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_OpeningDoor_2_2017-03-27_22-33-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_lateralFall_4_2016-06-15_21-35-33.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Walking_3_2016-05-29_20-45-38.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Sitting_GettingUpOnAChair_3_2016-06-15_21-51-18.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_Fall_backwardFall_6_2016-06-13_21-54-27.csv
# ...
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_forwardFall_8_2016-06-01_22-12-42.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Jogging_1_2016-06-07_21-19-28.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Sitting_GettingUpOnAChair_1_2016-06-07_21-09-20.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Jogging_4_2016-05-31_18-35-02.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_backwardFall_6_2016-06-15_21-39-26.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_LyingDown_OnABed_3_2016-06-13_21-18-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_Hopping_3_2016-06-03_19-42-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_15_ADL_OpeningDoor_3_2016-12-03_17-32-52.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_7_2016-06-01_22-51-58.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Bending_1_2016-06-13_21-09-01.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_11_Fall_backwardFall_5_2016-06-10_18-04-50.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_07_ADL_Hopping_1_2016-06-13_18-26-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_HandsUp_2_2017-04-14_23-33-21.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_06_ADL_Walking_1_2016-06-13_21-11-08.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_12_2016-06-01_22-58-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_lateralFall_3_2016-06-15_21-29-30.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Hopping_5_2016-05-31_18-40-23.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_Jogging_2_2016-06-07_21-20-09.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_01_ADL_Aplausing_2_2017-04-14_23-38-59.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_Fall_lateralFall_6_2016-06-07_21-37-14.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_Sitting_GettingUpOnAChair_2_2016-11-27_14-14-11.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_Bending_1_2016-06-04_15-06-27.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_Fall_backwardFall_1_2016-06-15_21-15-34.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_forwardFall_6_2016-06-13_13-23-05.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_OpeningDoor_5_2016-11-27_16-47-17.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_09_ADL_HandsUp_1_2017-03-27_22-30-14.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_03_ADL_MakingACall_2_2017-04-14_23-49-56.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_GoUpstairs_3_2016-06-06_15-34-49.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_Fall_forwardFall_1_2016-06-15_21-21-48.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_14_ADL_GoDownstairs_3_2016-06-03_19-54-28.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_04_Fall_forwardFall_2_2016-06-13_13-14-43.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_MakingACall_1_2017-04-19_16-46-55.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_19_ADL_HandsUp_1_2017-04-19_16-50-51.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_18_ADL_LyingDown_OnABed_3_2016-11-27_14-27-14.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_10_ADL_GoDownstairs_3_2016-06-06_15-55-32.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_02_Fall_backwardFall_2_2016-06-13_20-52-16.csv
# /content/drive/MyDrive/HAR_Dataset/UMAFALL/UMAFall_Subject_05_ADL_Aplausing_1_2016-11-28_16-32-03.csv
# Total subjects found: 18
#
# ================================================================================
# Processing all subjects...
# ================================================================================
# Subject 1: 282 windows generated.
# Subject 2: 731 windows generated.
# Subject 3: 266 windows generated.
# Subject 4: 607 windows generated.
# Subject 5: 717 windows generated.
# Subject 6: 742 windows generated.
# Subject 7: 476 windows generated.
# Subject 8: 148 windows generated.
# Subject 9: 177 windows generated.
# Subject 10: 43 windows generated.
# Subject 11: 515 windows generated.
# Subject 12: 178 windows generated.
# Subject 14: 454 windows generated.
# Subject 15: 490 windows generated.
# Subject 16: 154 windows generated.
# Subject 17: 297 windows generated.
# Subject 18: 1119 windows generated.
# Subject 19: 177 windows generated.
#
# ================================================================================
# Total windows generated (pre-split): 7573
# Class distribution (pre-split): [5089 2148  164  172]
#
# ================================================================================
# Scaling data...
# ================================================================================
#  ✓ Scaler fitted on train data and applied to all splits.
#
# ================================================================================
# Sampling data per class...
# ================================================================================
# Warning: Class 2 has only 105 samples. Using all 105 samples (Requested: 1000).
# Warning: Class 3 has only 110 samples. Using all 110 samples (Requested: 1000).
# Warning: Class 1 has only 344 samples. Using all 344 samples (Requested: 500).
# Warning: Class 2 has only 26 samples. Using all 26 samples (Requested: 500).
# Warning: Class 3 has only 28 samples. Using all 28 samples (Requested: 500).
# Warning: Class 1 has only 430 samples. Using all 430 samples (Requested: 500).
# Warning: Class 2 has only 33 samples. Using all 33 samples (Requested: 500).
# Warning: Class 3 has only 34 samples. Using all 34 samples (Requested: 500).
#
# ================================================================================
# Final Dataset Statistics
# ================================================================================
# Train: (2215, 40, 39), Class dist: [1000 1000  105  110]
# Val:   (898, 40, 39), Class dist: [500 344  26  28]
# Test:  (997, 40, 39), Class dist: [500 430  33  34]
#
# ================================================================================
# Build Model (TPA-Only)
# ================================================================================
# Input channels: 39
# Window size: 40
#  ✓ Parameters: 1,604,916
#  ✓ TPA: 3 layers, heads=8, dim=256
#
# ================================================================================
# Class Weights:
# ================================================================================
#  ADL    : 1.00
#  Fall   : 5.00
#  Pre    : 8.00
#  Post   : 8.00
#
# ================================================================================
# Training Start
# ================================================================================
# Epoch  1/100 | Train Loss: 0.9550 Acc: 54.04% | Val Loss: 1.0371 Acc: 65.70%
# Epoch  2/100 | Train Loss: 0.6791 Acc: 63.21% | Val Loss: 1.0024 Acc: 60.58%
# Epoch  3/100 | Train Loss: 0.6343 Acc: 64.51% | Val Loss: 0.9368 Acc: 63.03%
# Epoch  4/100 | Train Loss: 0.5635 Acc: 66.55% | Val Loss: 0.8623 Acc: 63.47%
# Epoch  5/100 | Train Loss: 0.5329 Acc: 69.30% | Val Loss: 0.8180 Acc: 67.04%
# Epoch  6/100 | Train Loss: 0.4857 Acc: 72.42% | Val Loss: 0.8369 Acc: 66.26%
# Epoch  7/100 | Train Loss: 0.4575 Acc: 71.29% | Val Loss: 0.8720 Acc: 62.81%
# Epoch  8/100 | Train Loss: 0.4109 Acc: 74.49% | Val Loss: 0.7543 Acc: 72.38%
# Epoch  9/100 | Train Loss: 0.3702 Acc: 78.24% | Val Loss: 0.7674 Acc: 68.71%
# Epoch 10/100 | Train Loss: 0.3418 Acc: 74.63% | Val Loss: 0.8086 Acc: 70.60%
# Epoch 11/100 | Train Loss: 0.2978 Acc: 78.74% | Val Loss: 0.7133 Acc: 75.28%
# Epoch 12/100 | Train Loss: 0.2621 Acc: 81.94% | Val Loss: 0.7424 Acc: 72.16%
# Epoch 13/100 | Train Loss: 0.2230 Acc: 82.66% | Val Loss: 0.7204 Acc: 74.39%
# Epoch 14/100 | Train Loss: 0.2001 Acc: 82.93% | Val Loss: 0.7107 Acc: 76.73%
# Epoch 15/100 | Train Loss: 0.1657 Acc: 88.40% | Val Loss: 0.7117 Acc: 76.84%
# Epoch 16/100 | Train Loss: 0.1468 Acc: 87.77% | Val Loss: 0.6760 Acc: 79.06%
# Epoch 17/100 | Train Loss: 0.1232 Acc: 91.47% | Val Loss: 0.7297 Acc: 78.17%
# Epoch 18/100 | Train Loss: 0.1008 Acc: 91.60% | Val Loss: 0.6824 Acc: 81.40%
# Epoch 19/100 | Train Loss: 0.0856 Acc: 94.22% | Val Loss: 0.6890 Acc: 81.96%
# Epoch 20/100 | Train Loss: 0.0728 Acc: 94.72% | Val Loss: 0.6503 Acc: 82.85%
# Epoch 21/100 | Train Loss: 0.0614 Acc: 96.03% | Val Loss: 0.6885 Acc: 82.41%
# Epoch 22/100 | Train Loss: 0.0491 Acc: 96.43% | Val Loss: 0.6667 Acc: 84.52%
# Epoch 23/100 | Train Loss: 0.0445 Acc: 97.34% | Val Loss: 0.7195 Acc: 82.29%
# Epoch 24/100 | Train Loss: 0.0418 Acc: 96.03% | Val Loss: 0.6933 Acc: 83.96%
# Epoch 25/100 | Train Loss: 0.0348 Acc: 97.97% | Val Loss: 0.7089 Acc: 82.85%
# Epoch 26/100 | Train Loss: 0.0300 Acc: 97.61% | Val Loss: 0.7330 Acc: 82.18%
# Epoch 27/100 | Train Loss: 0.0292 Acc: 97.92% | Val Loss: 0.7009 Acc: 84.30%
# Epoch 28/100 | Train Loss: 0.0256 Acc: 98.42% | Val Loss: 0.6912 Acc: 84.63%
# Epoch 29/100 | Train Loss: 0.0229 Acc: 98.51% | Val Loss: 0.6894 Acc: 84.30%
# Epoch 30/100 | Train Loss: 0.0200 Acc: 98.74% | Val Loss: 0.7031 Acc: 83.85%
# Epoch 31/100 | Train Loss: 0.0192 Acc: 98.65% | Val Loss: 0.7212 Acc: 83.85%
# Epoch 32/100 | Train Loss: 0.0175 Acc: 98.87% | Val Loss: 0.7089 Acc: 84.41%
# Epoch 33/100 | Train Loss: 0.0164 Acc: 99.23% | Val Loss: 0.7012 Acc: 84.30%
# Epoch 34/100 | Train Loss: 0.0153 Acc: 99.28% | Val Loss: 0.7022 Acc: 84.19%
# Epoch 35/100 | Train Loss: 0.0152 Acc: 99.01% | Val Loss: 0.7104 Acc: 84.08%
# Epoch 36/100 | Train Loss: 0.0140 Acc: 99.28% | Val Loss: 0.7125 Acc: 83.96%
# Epoch 37/100 | Train Loss: 0.0144 Acc: 99.14% | Val Loss: 0.7130 Acc: 83.85%
# Epoch 38/100 | Train Loss: 0.0140 Acc: 99.32% | Val Loss: 0.7112 Acc: 84.08%
# Epoch 39/100 | Train Loss: 0.0145 Acc: 99.28% | Val Loss: 0.7102 Acc: 83.85%
# Epoch 40/100 | Train Loss: 0.0135 Acc: 99.41% | Val Loss: 0.7120 Acc: 83.96%
# Epoch 41/100 | Train Loss: 0.0131 Acc: 99.37% | Val Loss: 0.7120 Acc: 83.85%
# Epoch 42/100 | Train Loss: 0.0132 Acc: 99.41% | Val Loss: 0.7131 Acc: 84.08%
# Epoch 43/100 | Train Loss: 0.0127 Acc: 99.41% | Val Loss: 0.7146 Acc: 84.19%
# Epoch 44/100 | Train Loss: 0.0134 Acc: 99.28% | Val Loss: 0.7147 Acc: 84.08%
# Epoch 45/100 | Train Loss: 0.0130 Acc: 99.50% | Val Loss: 0.7149 Acc: 84.08%
# Epoch 46/100 | Train Loss: 0.0133 Acc: 99.41% | Val Loss: 0.7153 Acc: 84.19%
# Epoch 47/100 | Train Loss: 0.0131 Acc: 99.46% | Val Loss: 0.7161 Acc: 84.19%
# Epoch 48/100 | Train Loss: 0.0122 Acc: 99.41% | Val Loss: 0.7173 Acc: 84.19%
# Epoch 49/100 | Train Loss: 0.0121 Acc: 99.46% | Val Loss: 0.7178 Acc: 84.19%
# Epoch 50/100 | Train Loss: 0.0128 Acc: 99.19% | Val Loss: 0.7178 Acc: 84.19%
# Epoch 51/100 | Train Loss: 0.0124 Acc: 99.37% | Val Loss: 0.7175 Acc: 84.19%
# Epoch 52/100 | Train Loss: 0.0128 Acc: 99.41% | Val Loss: 0.7172 Acc: 84.08%
# Epoch 53/100 | Train Loss: 0.0122 Acc: 99.55% | Val Loss: 0.7170 Acc: 84.08%
# Epoch 54/100 | Train Loss: 0.0126 Acc: 99.37% | Val Loss: 0.7169 Acc: 84.08%
# Epoch 55/100 | Train Loss: 0.0122 Acc: 99.37% | Val Loss: 0.7169 Acc: 84.08%
# Epoch 56/100 | Train Loss: 0.0132 Acc: 99.41% | Val Loss: 0.7167 Acc: 84.08%
# Epoch 57/100 | Train Loss: 0.0126 Acc: 99.37% | Val Loss: 0.7166 Acc: 84.08%
# Epoch 58/100 | Train Loss: 0.0126 Acc: 99.59% | Val Loss: 0.7166 Acc: 84.08%
# Epoch 59/100 | Train Loss: 0.0120 Acc: 99.46% | Val Loss: 0.7166 Acc: 84.08%
# Epoch 60/100 | Train Loss: 0.0114 Acc: 99.46% | Val Loss: 0.7166 Acc: 84.08%
# Epoch 61/100 | Train Loss: 0.0118 Acc: 99.41% | Val Loss: 0.7166 Acc: 84.08%
# Epoch 62/100 | Train Loss: 0.0122 Acc: 99.50% | Val Loss: 0.7165 Acc: 84.08%
# Epoch 63/100 | Train Loss: 0.0126 Acc: 99.41% | Val Loss: 0.7165 Acc: 84.08%
# Epoch 64/100 | Train Loss: 0.0120 Acc: 99.50% | Val Loss: 0.7165 Acc: 84.08%
# Epoch 65/100 | Train Loss: 0.0128 Acc: 99.46% | Val Loss: 0.7165 Acc: 84.08%
# Epoch 66/100 | Train Loss: 0.0126 Acc: 99.37% | Val Loss: 0.7165 Acc: 84.08%
# Epoch 67/100 | Train Loss: 0.0120 Acc: 99.41% | Val Loss: 0.7165 Acc: 84.08%
# Epoch 68/100 | Train Loss: 0.0122 Acc: 99.50% | Val Loss: 0.7165 Acc: 84.08%
# Epoch 69/100 | Train Loss: 0.0118 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 70/100 | Train Loss: 0.0123 Acc: 99.37% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 71/100 | Train Loss: 0.0131 Acc: 99.28% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 72/100 | Train Loss: 0.0128 Acc: 99.37% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 73/100 | Train Loss: 0.0135 Acc: 99.32% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 74/100 | Train Loss: 0.0127 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 75/100 | Train Loss: 0.0124 Acc: 99.32% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 76/100 | Train Loss: 0.0123 Acc: 99.41% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 77/100 | Train Loss: 0.0131 Acc: 99.41% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 78/100 | Train Loss: 0.0131 Acc: 99.32% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 79/100 | Train Loss: 0.0127 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 80/100 | Train Loss: 0.0133 Acc: 99.32% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 81/100 | Train Loss: 0.0120 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 82/100 | Train Loss: 0.0120 Acc: 99.41% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 83/100 | Train Loss: 0.0112 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 84/100 | Train Loss: 0.0123 Acc: 99.50% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 85/100 | Train Loss: 0.0118 Acc: 99.28% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 86/100 | Train Loss: 0.0130 Acc: 99.23% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 87/100 | Train Loss: 0.0125 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 88/100 | Train Loss: 0.0120 Acc: 99.28% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 89/100 | Train Loss: 0.0124 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 90/100 | Train Loss: 0.0129 Acc: 99.50% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 91/100 | Train Loss: 0.0125 Acc: 99.37% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 92/100 | Train Loss: 0.0119 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 93/100 | Train Loss: 0.0113 Acc: 99.59% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 94/100 | Train Loss: 0.0120 Acc: 99.41% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 95/100 | Train Loss: 0.0118 Acc: 99.55% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 96/100 | Train Loss: 0.0130 Acc: 99.50% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 97/100 | Train Loss: 0.0123 Acc: 99.50% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 98/100 | Train Loss: 0.0119 Acc: 99.46% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 99/100 | Train Loss: 0.0129 Acc: 99.37% | Val Loss: 0.7164 Acc: 84.08%
# Epoch 100/100 | Train Loss: 0.0125 Acc: 99.41% | Val Loss: 0.7164 Acc: 84.08%
#
# ================================================================================
# Best Validation Accuracy: 84.63% at Epoch 28
# ================================================================================
#
# ================================================================================
# Test Set Performance
# ================================================================================
# Test Loss: 0.6772
# Test Accuracy: 84.65%
#
#               precision    recall  f1-score   support
#
#          ADL     0.8918    0.8240    0.8565       500
#         Fall     0.9077    0.9372    0.9222       430
#     Pre-fall     0.2500    0.3939    0.3059        33
#    Post-fall     0.4103    0.4706    0.4384        34
#
#     accuracy                         0.8465       997
#    macro avg     0.6149    0.6564    0.6307       997
# weighted avg     0.8610    0.8465    0.8524       997
#
#
# Confusion matrix saved to 'confusion_matrix.png'
#
# Model Statistics:
#   Params (M):  1.60
#   FLOPs (M):   64.05
#   Inference (ms): 2.84
#
# ================================================================================
# Generating Attention Plots...
# ================================================================================
# Attention plots saved to 'attention_plots/' directory.
